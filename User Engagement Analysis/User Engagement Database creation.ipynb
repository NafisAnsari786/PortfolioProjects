# %% [markdown]
# ### <span style="color:GoldenRod ">**User Engagement Analysis Database**</span>

# %%
import pandas as pd
import json 
from sqlalchemy import create_engine

# %%
file_paths = {
    'business': r'F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_business.json',
    'checkin': r"F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_checkin.json",
    'review': r'F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_review.json',
    'tip': r"F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_tip.json",
    'user': r"F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_user.json"
}

# %%
# Comsumed too much resources for loading the dataset

# with open(file_paths['business'], 'r') as f:
#     business_data = [json.loads(line) for line in f]
# business_df = pd.DataFrame(business_data)

# with open(file_paths['checkin'], 'r') as f:
#     checkin_data = [json.loads(line) for line in f]
# checkin_df = pd.DataFrame(checkin_data)

# with open(file_paths['review'], 'r') as f:
#     review_data = [json.loads(line) for line in f]
# review_df = pd.DataFrame(review_data)

# with open(file_paths['tip'], 'r') as f:
#     tip_data = [json.loads(line) for line in f]
# tip_df = pd.DataFrame(tip_data)

# with open(file_paths['user'], 'r') as f:
#     user_data = [json.loads(line) for line in f]
# user_df = pd.DataFrame(user_data)

# %%
# # Create engine for SQLlite 
# engine = create_engine('sqlite:///yelp.db')

# # Function to load DataFrame into SQL
# def load_dataframe(df, table_name, engine):
#     df.to_sql(table_name, con=engine, if_exists='replace', index=False)

# # Load each DataFrame into a separate table
# load_dataframe(business_df, 'business', engine)
# load_dataframe(review_df, 'review', engine)
# load_dataframe(user_df, 'user', engine)
# load_dataframe(tip_df, 'tip', engine)
# load_dataframe(checkin_df, 'checkin', engine)

# %%
# Example query to check loaded data
df = pd.read_sql('SELECT business_id, attributes, hours FROM business LIMIT 5', con=engine)
df

# Convert JSON strings back to Python objects if needed
df['attributes'] = df['attributes'].apply(lambda x: json.loads(x) if x else {})
print(df['attributes'])
# Out:
# 0                        {'ByAppointmentOnly': 'True'}
# 1               {'BusinessAcceptsCreditCards': 'True'}
# 2    {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3    {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4    {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# Name: attributes, dtype: object

# %%
# To delete the database
# import os 

# # Delete the existing database file
# db_path = 'yelp_optimized.db'
# if os.path.exists(db_path):
#     os.remove(db_path)
#     print(f"Database '{db_path}' deleted successfully.")
# else:
#     print(f"Database '{db_path}' does not exist.")
# Out:
# Database 'yelp_optimized.db' deleted successfully.

# %%
import json
import pandas as pd
from sqlalchemy import create_engine

# Create a database connection using SQLite
engine = create_engine('sqlite:///yelp_optimized.db')

# Function to handle preprocessing of nested fields (like dictionaries or lists)
def preprocess_chunk(chunk):
    # Drop unwanted columns
    chunk = chunk.drop(columns=['attributes', 'hours'], errors='ignore')

    for col in chunk.columns:
        if chunk[col].dtype == 'object':    # Check if the column contains object data type
            # Convert dictionaries or lists to JSON strings for storage in the database
            chunk[col] = chunk[col].apply(lambda x: json.dumps(x) if isinstance(x, (dict, list)) else x)
    return chunk

# Function to process large JSON files in manageable chunks
def process_json_file(file_path, table_name, chunk_size=10000):
    """
    Reads a large JSON file line by line, processes it in chunks, 
    and loads the data into a database table.

    Parameters:
    - file_path: Path to the JSON file
    - table_name: Name of the database table to insert data into
    - chunk_size: Number of rows to process at a time
    """
    print(f"Processing {file_path} for table {table_name}")     # Log progress
    chunk = []      # Temporary storage for rows in the current chunk

    # Open the JSON file and read it line by line
    with open(file_path, 'r') as f:
        for i, line in enumerate(f):
            # Parse each line as JSON and append it to the chunk
            chunk.append(json.loads(line))
            
            # If the chunk reaches the specified size, process and load it into the database
            if len(chunk) >= chunk_size:
                df = pd.DataFrame(chunk)    # Convert the chunk to a DataFrame
                df = preprocess_chunk(df)  # Preprocess nested fields and drop columns
                df.to_sql(table_name, con=engine, if_exists='append', index=False)
                chunk = []  # Clear the chunk after processing
                print(f"Processed {i+1} rows into {table_name}")    # Log progress
        
        # After the loop, process any remaining rows in the chunk
        if chunk:
            df = pd.DataFrame(chunk)
            df = preprocess_chunk(df)  # Preprocess nested fields and drop columns
            df.to_sql(table_name, con=engine, if_exists='append', index=False)      # Load to database
            print(f"Processed {len(chunk)} remaining rows into {table_name}")       # Log progress

# Define file paths for the JSON datasets
file_paths = {
    'business': r'F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_business.json',
    'checkin': r"F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_checkin.json",
    'review': r'F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_review.json',
    'tip': r"F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_tip.json",
    'user': r"F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_user.json"
}

# Process each JSON dataset and load it into the respective database table
process_json_file(file_paths['business'], 'business')
process_json_file(file_paths['checkin'], 'checkin')
process_json_file(file_paths['review'], 'review')
process_json_file(file_paths['tip'], 'tip')
process_json_file(file_paths['user'], 'user')

# Print a message once all datasets have been processed
print("All datasets processed and loaded into the database.")
# Out:
# Processing F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_business.json for table business
# Processed 10000 rows into business
# Processed 20000 rows into business
# Processed 30000 rows into business
# Processed 40000 rows into business
# Processed 50000 rows into business
# Processed 60000 rows into business
# Processed 70000 rows into business
# Processed 80000 rows into business
# Processed 90000 rows into business
# Processed 100000 rows into business
# Processed 110000 rows into business
# Processed 120000 rows into business
# Processed 130000 rows into business
# Processed 140000 rows into business
# Processed 150000 rows into business
# Processed 346 remaining rows into business
# Processing F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_checkin.json for table checkin
# Processed 10000 rows into checkin
# Processed 20000 rows into checkin
# Processed 30000 rows into checkin
# Processed 40000 rows into checkin
# Processed 50000 rows into checkin
# Processed 60000 rows into checkin
# Processed 70000 rows into checkin
# Processed 80000 rows into checkin
# Processed 90000 rows into checkin
# Processed 100000 rows into checkin
# Processed 110000 rows into checkin
# Processed 120000 rows into checkin
# Processed 130000 rows into checkin
# Processed 1930 remaining rows into checkin
# Processing F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_review.json for table review
# Processed 10000 rows into review
# Processed 20000 rows into review
# Processed 30000 rows into review
# Processed 40000 rows into review
# Processed 50000 rows into review
# Processed 60000 rows into review
# Processed 70000 rows into review
# Processed 80000 rows into review
# Processed 90000 rows into review
# Processed 100000 rows into review
# Processed 110000 rows into review
# Processed 120000 rows into review
# Processed 130000 rows into review
# Processed 140000 rows into review
# Processed 150000 rows into review
# Processed 160000 rows into review
# Processed 170000 rows into review
# Processed 180000 rows into review
# Processed 190000 rows into review
# Processed 200000 rows into review
# Processed 210000 rows into review
# Processed 220000 rows into review
# Processed 230000 rows into review
# Processed 240000 rows into review
# Processed 250000 rows into review
# Processed 260000 rows into review
# Processed 270000 rows into review
# Processed 280000 rows into review
# Processed 290000 rows into review
# Processed 300000 rows into review
# Processed 310000 rows into review
# Processed 320000 rows into review
# Processed 330000 rows into review
# Processed 340000 rows into review
# Processed 350000 rows into review
# Processed 360000 rows into review
# Processed 370000 rows into review
# Processed 380000 rows into review
# Processed 390000 rows into review
# Processed 400000 rows into review
# Processed 410000 rows into review
# Processed 420000 rows into review
# Processed 430000 rows into review
# Processed 440000 rows into review
# Processed 450000 rows into review
# Processed 460000 rows into review
# Processed 470000 rows into review
# Processed 480000 rows into review
# Processed 490000 rows into review
# Processed 500000 rows into review
# Processed 510000 rows into review
# Processed 520000 rows into review
# Processed 530000 rows into review
# Processed 540000 rows into review
# Processed 550000 rows into review
# Processed 560000 rows into review
# Processed 570000 rows into review
# Processed 580000 rows into review
# Processed 590000 rows into review
# Processed 600000 rows into review
# Processed 610000 rows into review
# Processed 620000 rows into review
# Processed 630000 rows into review
# Processed 640000 rows into review
# Processed 650000 rows into review
# Processed 660000 rows into review
# Processed 670000 rows into review
# Processed 680000 rows into review
# Processed 690000 rows into review
# Processed 700000 rows into review
# Processed 710000 rows into review
# Processed 720000 rows into review
# Processed 730000 rows into review
# Processed 740000 rows into review
# Processed 750000 rows into review
# Processed 760000 rows into review
# Processed 770000 rows into review
# Processed 780000 rows into review
# Processed 790000 rows into review
# Processed 800000 rows into review
# Processed 810000 rows into review
# Processed 820000 rows into review
# Processed 830000 rows into review
# Processed 840000 rows into review
# Processed 850000 rows into review
# Processed 860000 rows into review
# Processed 870000 rows into review
# Processed 880000 rows into review
# Processed 890000 rows into review
# Processed 900000 rows into review
# Processed 910000 rows into review
# Processed 920000 rows into review
# Processed 930000 rows into review
# Processed 940000 rows into review
# Processed 950000 rows into review
# Processed 960000 rows into review
# Processed 970000 rows into review
# Processed 980000 rows into review
# Processed 990000 rows into review
# Processed 1000000 rows into review
# Processed 1010000 rows into review
# Processed 1020000 rows into review
# Processed 1030000 rows into review
# Processed 1040000 rows into review
# Processed 1050000 rows into review
# Processed 1060000 rows into review
# Processed 1070000 rows into review
# Processed 1080000 rows into review
# Processed 1090000 rows into review
# Processed 1100000 rows into review
# Processed 1110000 rows into review
# Processed 1120000 rows into review
# Processed 1130000 rows into review
# Processed 1140000 rows into review
# Processed 1150000 rows into review
# Processed 1160000 rows into review
# Processed 1170000 rows into review
# Processed 1180000 rows into review
# Processed 1190000 rows into review
# Processed 1200000 rows into review
# Processed 1210000 rows into review
# Processed 1220000 rows into review
# Processed 1230000 rows into review
# Processed 1240000 rows into review
# Processed 1250000 rows into review
# Processed 1260000 rows into review
# Processed 1270000 rows into review
# Processed 1280000 rows into review
# Processed 1290000 rows into review
# Processed 1300000 rows into review
# Processed 1310000 rows into review
# Processed 1320000 rows into review
# Processed 1330000 rows into review
# Processed 1340000 rows into review
# Processed 1350000 rows into review
# Processed 1360000 rows into review
# Processed 1370000 rows into review
# Processed 1380000 rows into review
# Processed 1390000 rows into review
# Processed 1400000 rows into review
# Processed 1410000 rows into review
# Processed 1420000 rows into review
# Processed 1430000 rows into review
# Processed 1440000 rows into review
# Processed 1450000 rows into review
# Processed 1460000 rows into review
# Processed 1470000 rows into review
# Processed 1480000 rows into review
# Processed 1490000 rows into review
# Processed 1500000 rows into review
# Processed 1510000 rows into review
# Processed 1520000 rows into review
# Processed 1530000 rows into review
# Processed 1540000 rows into review
# Processed 1550000 rows into review
# Processed 1560000 rows into review
# Processed 1570000 rows into review
# Processed 1580000 rows into review
# Processed 1590000 rows into review
# Processed 1600000 rows into review
# Processed 1610000 rows into review
# Processed 1620000 rows into review
# Processed 1630000 rows into review
# Processed 1640000 rows into review
# Processed 1650000 rows into review
# Processed 1660000 rows into review
# Processed 1670000 rows into review
# Processed 1680000 rows into review
# Processed 1690000 rows into review
# Processed 1700000 rows into review
# Processed 1710000 rows into review
# Processed 1720000 rows into review
# Processed 1730000 rows into review
# Processed 1740000 rows into review
# Processed 1750000 rows into review
# Processed 1760000 rows into review
# Processed 1770000 rows into review
# Processed 1780000 rows into review
# Processed 1790000 rows into review
# Processed 1800000 rows into review
# Processed 1810000 rows into review
# Processed 1820000 rows into review
# Processed 1830000 rows into review
# Processed 1840000 rows into review
# Processed 1850000 rows into review
# Processed 1860000 rows into review
# Processed 1870000 rows into review
# Processed 1880000 rows into review
# Processed 1890000 rows into review
# Processed 1900000 rows into review
# Processed 1910000 rows into review
# Processed 1920000 rows into review
# Processed 1930000 rows into review
# Processed 1940000 rows into review
# Processed 1950000 rows into review
# Processed 1960000 rows into review
# Processed 1970000 rows into review
# Processed 1980000 rows into review
# Processed 1990000 rows into review
# Processed 2000000 rows into review
# Processed 2010000 rows into review
# Processed 2020000 rows into review
# Processed 2030000 rows into review
# Processed 2040000 rows into review
# Processed 2050000 rows into review
# Processed 2060000 rows into review
# Processed 2070000 rows into review
# Processed 2080000 rows into review
# Processed 2090000 rows into review
# Processed 2100000 rows into review
# Processed 2110000 rows into review
# Processed 2120000 rows into review
# Processed 2130000 rows into review
# Processed 2140000 rows into review
# Processed 2150000 rows into review
# Processed 2160000 rows into review
# Processed 2170000 rows into review
# Processed 2180000 rows into review
# Processed 2190000 rows into review
# Processed 2200000 rows into review
# Processed 2210000 rows into review
# Processed 2220000 rows into review
# Processed 2230000 rows into review
# Processed 2240000 rows into review
# Processed 2250000 rows into review
# Processed 2260000 rows into review
# Processed 2270000 rows into review
# Processed 2280000 rows into review
# Processed 2290000 rows into review
# Processed 2300000 rows into review
# Processed 2310000 rows into review
# Processed 2320000 rows into review
# Processed 2330000 rows into review
# Processed 2340000 rows into review
# Processed 2350000 rows into review
# Processed 2360000 rows into review
# Processed 2370000 rows into review
# Processed 2380000 rows into review
# Processed 2390000 rows into review
# Processed 2400000 rows into review
# Processed 2410000 rows into review
# Processed 2420000 rows into review
# Processed 2430000 rows into review
# Processed 2440000 rows into review
# Processed 2450000 rows into review
# Processed 2460000 rows into review
# Processed 2470000 rows into review
# Processed 2480000 rows into review
# Processed 2490000 rows into review
# Processed 2500000 rows into review
# Processed 2510000 rows into review
# Processed 2520000 rows into review
# Processed 2530000 rows into review
# Processed 2540000 rows into review
# Processed 2550000 rows into review
# Processed 2560000 rows into review
# Processed 2570000 rows into review
# Processed 2580000 rows into review
# Processed 2590000 rows into review
# Processed 2600000 rows into review
# Processed 2610000 rows into review
# Processed 2620000 rows into review
# Processed 2630000 rows into review
# Processed 2640000 rows into review
# Processed 2650000 rows into review
# Processed 2660000 rows into review
# Processed 2670000 rows into review
# Processed 2680000 rows into review
# Processed 2690000 rows into review
# Processed 2700000 rows into review
# Processed 2710000 rows into review
# Processed 2720000 rows into review
# Processed 2730000 rows into review
# Processed 2740000 rows into review
# Processed 2750000 rows into review
# Processed 2760000 rows into review
# Processed 2770000 rows into review
# Processed 2780000 rows into review
# Processed 2790000 rows into review
# Processed 2800000 rows into review
# Processed 2810000 rows into review
# Processed 2820000 rows into review
# Processed 2830000 rows into review
# Processed 2840000 rows into review
# Processed 2850000 rows into review
# Processed 2860000 rows into review
# Processed 2870000 rows into review
# Processed 2880000 rows into review
# Processed 2890000 rows into review
# Processed 2900000 rows into review
# Processed 2910000 rows into review
# Processed 2920000 rows into review
# Processed 2930000 rows into review
# Processed 2940000 rows into review
# Processed 2950000 rows into review
# Processed 2960000 rows into review
# Processed 2970000 rows into review
# Processed 2980000 rows into review
# Processed 2990000 rows into review
# Processed 3000000 rows into review
# Processed 3010000 rows into review
# Processed 3020000 rows into review
# Processed 3030000 rows into review
# Processed 3040000 rows into review
# Processed 3050000 rows into review
# Processed 3060000 rows into review
# Processed 3070000 rows into review
# Processed 3080000 rows into review
# Processed 3090000 rows into review
# Processed 3100000 rows into review
# Processed 3110000 rows into review
# Processed 3120000 rows into review
# Processed 3130000 rows into review
# Processed 3140000 rows into review
# Processed 3150000 rows into review
# Processed 3160000 rows into review
# Processed 3170000 rows into review
# Processed 3180000 rows into review
# Processed 3190000 rows into review
# Processed 3200000 rows into review
# Processed 3210000 rows into review
# Processed 3220000 rows into review
# Processed 3230000 rows into review
# Processed 3240000 rows into review
# Processed 3250000 rows into review
# Processed 3260000 rows into review
# Processed 3270000 rows into review
# Processed 3280000 rows into review
# Processed 3290000 rows into review
# Processed 3300000 rows into review
# Processed 3310000 rows into review
# Processed 3320000 rows into review
# Processed 3330000 rows into review
# Processed 3340000 rows into review
# Processed 3350000 rows into review
# Processed 3360000 rows into review
# Processed 3370000 rows into review
# Processed 3380000 rows into review
# Processed 3390000 rows into review
# Processed 3400000 rows into review
# Processed 3410000 rows into review
# Processed 3420000 rows into review
# Processed 3430000 rows into review
# Processed 3440000 rows into review
# Processed 3450000 rows into review
# Processed 3460000 rows into review
# Processed 3470000 rows into review
# Processed 3480000 rows into review
# Processed 3490000 rows into review
# Processed 3500000 rows into review
# Processed 3510000 rows into review
# Processed 3520000 rows into review
# Processed 3530000 rows into review
# Processed 3540000 rows into review
# Processed 3550000 rows into review
# Processed 3560000 rows into review
# Processed 3570000 rows into review
# Processed 3580000 rows into review
# Processed 3590000 rows into review
# Processed 3600000 rows into review
# Processed 3610000 rows into review
# Processed 3620000 rows into review
# Processed 3630000 rows into review
# Processed 3640000 rows into review
# Processed 3650000 rows into review
# Processed 3660000 rows into review
# Processed 3670000 rows into review
# Processed 3680000 rows into review
# Processed 3690000 rows into review
# Processed 3700000 rows into review
# Processed 3710000 rows into review
# Processed 3720000 rows into review
# Processed 3730000 rows into review
# Processed 3740000 rows into review
# Processed 3750000 rows into review
# Processed 3760000 rows into review
# Processed 3770000 rows into review
# Processed 3780000 rows into review
# Processed 3790000 rows into review
# Processed 3800000 rows into review
# Processed 3810000 rows into review
# Processed 3820000 rows into review
# Processed 3830000 rows into review
# Processed 3840000 rows into review
# Processed 3850000 rows into review
# Processed 3860000 rows into review
# Processed 3870000 rows into review
# Processed 3880000 rows into review
# Processed 3890000 rows into review
# Processed 3900000 rows into review
# Processed 3910000 rows into review
# Processed 3920000 rows into review
# Processed 3930000 rows into review
# Processed 3940000 rows into review
# Processed 3950000 rows into review
# Processed 3960000 rows into review
# Processed 3970000 rows into review
# Processed 3980000 rows into review
# Processed 3990000 rows into review
# Processed 4000000 rows into review
# Processed 4010000 rows into review
# Processed 4020000 rows into review
# Processed 4030000 rows into review
# Processed 4040000 rows into review
# Processed 4050000 rows into review
# Processed 4060000 rows into review
# Processed 4070000 rows into review
# Processed 4080000 rows into review
# Processed 4090000 rows into review
# Processed 4100000 rows into review
# Processed 4110000 rows into review
# Processed 4120000 rows into review
# Processed 4130000 rows into review
# Processed 4140000 rows into review
# Processed 4150000 rows into review
# Processed 4160000 rows into review
# Processed 4170000 rows into review
# Processed 4180000 rows into review
# Processed 4190000 rows into review
# Processed 4200000 rows into review
# Processed 4210000 rows into review
# Processed 4220000 rows into review
# Processed 4230000 rows into review
# Processed 4240000 rows into review
# Processed 4250000 rows into review
# Processed 4260000 rows into review
# Processed 4270000 rows into review
# Processed 4280000 rows into review
# Processed 4290000 rows into review
# Processed 4300000 rows into review
# Processed 4310000 rows into review
# Processed 4320000 rows into review
# Processed 4330000 rows into review
# Processed 4340000 rows into review
# Processed 4350000 rows into review
# Processed 4360000 rows into review
# Processed 4370000 rows into review
# Processed 4380000 rows into review
# Processed 4390000 rows into review
# Processed 4400000 rows into review
# Processed 4410000 rows into review
# Processed 4420000 rows into review
# Processed 4430000 rows into review
# Processed 4440000 rows into review
# Processed 4450000 rows into review
# Processed 4460000 rows into review
# Processed 4470000 rows into review
# Processed 4480000 rows into review
# Processed 4490000 rows into review
# Processed 4500000 rows into review
# Processed 4510000 rows into review
# Processed 4520000 rows into review
# Processed 4530000 rows into review
# Processed 4540000 rows into review
# Processed 4550000 rows into review
# Processed 4560000 rows into review
# Processed 4570000 rows into review
# Processed 4580000 rows into review
# Processed 4590000 rows into review
# Processed 4600000 rows into review
# Processed 4610000 rows into review
# Processed 4620000 rows into review
# Processed 4630000 rows into review
# Processed 4640000 rows into review
# Processed 4650000 rows into review
# Processed 4660000 rows into review
# Processed 4670000 rows into review
# Processed 4680000 rows into review
# Processed 4690000 rows into review
# Processed 4700000 rows into review
# Processed 4710000 rows into review
# Processed 4720000 rows into review
# Processed 4730000 rows into review
# Processed 4740000 rows into review
# Processed 4750000 rows into review
# Processed 4760000 rows into review
# Processed 4770000 rows into review
# Processed 4780000 rows into review
# Processed 4790000 rows into review
# Processed 4800000 rows into review
# Processed 4810000 rows into review
# Processed 4820000 rows into review
# Processed 4830000 rows into review
# Processed 4840000 rows into review
# Processed 4850000 rows into review
# Processed 4860000 rows into review
# Processed 4870000 rows into review
# Processed 4880000 rows into review
# Processed 4890000 rows into review
# Processed 4900000 rows into review
# Processed 4910000 rows into review
# Processed 4920000 rows into review
# Processed 4930000 rows into review
# Processed 4940000 rows into review
# Processed 4950000 rows into review
# Processed 4960000 rows into review
# Processed 4970000 rows into review
# Processed 4980000 rows into review
# Processed 4990000 rows into review
# Processed 5000000 rows into review
# Processed 5010000 rows into review
# Processed 5020000 rows into review
# Processed 5030000 rows into review
# Processed 5040000 rows into review
# Processed 5050000 rows into review
# Processed 5060000 rows into review
# Processed 5070000 rows into review
# Processed 5080000 rows into review
# Processed 5090000 rows into review
# Processed 5100000 rows into review
# Processed 5110000 rows into review
# Processed 5120000 rows into review
# Processed 5130000 rows into review
# Processed 5140000 rows into review
# Processed 5150000 rows into review
# Processed 5160000 rows into review
# Processed 5170000 rows into review
# Processed 5180000 rows into review
# Processed 5190000 rows into review
# Processed 5200000 rows into review
# Processed 5210000 rows into review
# Processed 5220000 rows into review
# Processed 5230000 rows into review
# Processed 5240000 rows into review
# Processed 5250000 rows into review
# Processed 5260000 rows into review
# Processed 5270000 rows into review
# Processed 5280000 rows into review
# Processed 5290000 rows into review
# Processed 5300000 rows into review
# Processed 5310000 rows into review
# Processed 5320000 rows into review
# Processed 5330000 rows into review
# Processed 5340000 rows into review
# Processed 5350000 rows into review
# Processed 5360000 rows into review
# Processed 5370000 rows into review
# Processed 5380000 rows into review
# Processed 5390000 rows into review
# Processed 5400000 rows into review
# Processed 5410000 rows into review
# Processed 5420000 rows into review
# Processed 5430000 rows into review
# Processed 5440000 rows into review
# Processed 5450000 rows into review
# Processed 5460000 rows into review
# Processed 5470000 rows into review
# Processed 5480000 rows into review
# Processed 5490000 rows into review
# Processed 5500000 rows into review
# Processed 5510000 rows into review
# Processed 5520000 rows into review
# Processed 5530000 rows into review
# Processed 5540000 rows into review
# Processed 5550000 rows into review
# Processed 5560000 rows into review
# Processed 5570000 rows into review
# Processed 5580000 rows into review
# Processed 5590000 rows into review
# Processed 5600000 rows into review
# Processed 5610000 rows into review
# Processed 5620000 rows into review
# Processed 5630000 rows into review
# Processed 5640000 rows into review
# Processed 5650000 rows into review
# Processed 5660000 rows into review
# Processed 5670000 rows into review
# Processed 5680000 rows into review
# Processed 5690000 rows into review
# Processed 5700000 rows into review
# Processed 5710000 rows into review
# Processed 5720000 rows into review
# Processed 5730000 rows into review
# Processed 5740000 rows into review
# Processed 5750000 rows into review
# Processed 5760000 rows into review
# Processed 5770000 rows into review
# Processed 5780000 rows into review
# Processed 5790000 rows into review
# Processed 5800000 rows into review
# Processed 5810000 rows into review
# Processed 5820000 rows into review
# Processed 5830000 rows into review
# Processed 5840000 rows into review
# Processed 5850000 rows into review
# Processed 5860000 rows into review
# Processed 5870000 rows into review
# Processed 5880000 rows into review
# Processed 5890000 rows into review
# Processed 5900000 rows into review
# Processed 5910000 rows into review
# Processed 5920000 rows into review
# Processed 5930000 rows into review
# Processed 5940000 rows into review
# Processed 5950000 rows into review
# Processed 5960000 rows into review
# Processed 5970000 rows into review
# Processed 5980000 rows into review
# Processed 5990000 rows into review
# Processed 6000000 rows into review
# Processed 6010000 rows into review
# Processed 6020000 rows into review
# Processed 6030000 rows into review
# Processed 6040000 rows into review
# Processed 6050000 rows into review
# Processed 6060000 rows into review
# Processed 6070000 rows into review
# Processed 6080000 rows into review
# Processed 6090000 rows into review
# Processed 6100000 rows into review
# Processed 6110000 rows into review
# Processed 6120000 rows into review
# Processed 6130000 rows into review
# Processed 6140000 rows into review
# Processed 6150000 rows into review
# Processed 6160000 rows into review
# Processed 6170000 rows into review
# Processed 6180000 rows into review
# Processed 6190000 rows into review
# Processed 6200000 rows into review
# Processed 6210000 rows into review
# Processed 6220000 rows into review
# Processed 6230000 rows into review
# Processed 6240000 rows into review
# Processed 6250000 rows into review
# Processed 6260000 rows into review
# Processed 6270000 rows into review
# Processed 6280000 rows into review
# Processed 6290000 rows into review
# Processed 6300000 rows into review
# Processed 6310000 rows into review
# Processed 6320000 rows into review
# Processed 6330000 rows into review
# Processed 6340000 rows into review
# Processed 6350000 rows into review
# Processed 6360000 rows into review
# Processed 6370000 rows into review
# Processed 6380000 rows into review
# Processed 6390000 rows into review
# Processed 6400000 rows into review
# Processed 6410000 rows into review
# Processed 6420000 rows into review
# Processed 6430000 rows into review
# Processed 6440000 rows into review
# Processed 6450000 rows into review
# Processed 6460000 rows into review
# Processed 6470000 rows into review
# Processed 6480000 rows into review
# Processed 6490000 rows into review
# Processed 6500000 rows into review
# Processed 6510000 rows into review
# Processed 6520000 rows into review
# Processed 6530000 rows into review
# Processed 6540000 rows into review
# Processed 6550000 rows into review
# Processed 6560000 rows into review
# Processed 6570000 rows into review
# Processed 6580000 rows into review
# Processed 6590000 rows into review
# Processed 6600000 rows into review
# Processed 6610000 rows into review
# Processed 6620000 rows into review
# Processed 6630000 rows into review
# Processed 6640000 rows into review
# Processed 6650000 rows into review
# Processed 6660000 rows into review
# Processed 6670000 rows into review
# Processed 6680000 rows into review
# Processed 6690000 rows into review
# Processed 6700000 rows into review
# Processed 6710000 rows into review
# Processed 6720000 rows into review
# Processed 6730000 rows into review
# Processed 6740000 rows into review
# Processed 6750000 rows into review
# Processed 6760000 rows into review
# Processed 6770000 rows into review
# Processed 6780000 rows into review
# Processed 6790000 rows into review
# Processed 6800000 rows into review
# Processed 6810000 rows into review
# Processed 6820000 rows into review
# Processed 6830000 rows into review
# Processed 6840000 rows into review
# Processed 6850000 rows into review
# Processed 6860000 rows into review
# Processed 6870000 rows into review
# Processed 6880000 rows into review
# Processed 6890000 rows into review
# Processed 6900000 rows into review
# Processed 6910000 rows into review
# Processed 6920000 rows into review
# Processed 6930000 rows into review
# Processed 6940000 rows into review
# Processed 6950000 rows into review
# Processed 6960000 rows into review
# Processed 6970000 rows into review
# Processed 6980000 rows into review
# Processed 6990000 rows into review
# Processed 280 remaining rows into review
# Processing F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_tip.json for table tip
# Processed 10000 rows into tip
# Processed 20000 rows into tip
# Processed 30000 rows into tip
# Processed 40000 rows into tip
# Processed 50000 rows into tip
# Processed 60000 rows into tip
# Processed 70000 rows into tip
# Processed 80000 rows into tip
# Processed 90000 rows into tip
# Processed 100000 rows into tip
# Processed 110000 rows into tip
# Processed 120000 rows into tip
# Processed 130000 rows into tip
# Processed 140000 rows into tip
# Processed 150000 rows into tip
# Processed 160000 rows into tip
# Processed 170000 rows into tip
# Processed 180000 rows into tip
# Processed 190000 rows into tip
# Processed 200000 rows into tip
# Processed 210000 rows into tip
# Processed 220000 rows into tip
# Processed 230000 rows into tip
# Processed 240000 rows into tip
# Processed 250000 rows into tip
# Processed 260000 rows into tip
# Processed 270000 rows into tip
# Processed 280000 rows into tip
# Processed 290000 rows into tip
# Processed 300000 rows into tip
# Processed 310000 rows into tip
# Processed 320000 rows into tip
# Processed 330000 rows into tip
# Processed 340000 rows into tip
# Processed 350000 rows into tip
# Processed 360000 rows into tip
# Processed 370000 rows into tip
# Processed 380000 rows into tip
# Processed 390000 rows into tip
# Processed 400000 rows into tip
# Processed 410000 rows into tip
# Processed 420000 rows into tip
# Processed 430000 rows into tip
# Processed 440000 rows into tip
# Processed 450000 rows into tip
# Processed 460000 rows into tip
# Processed 470000 rows into tip
# Processed 480000 rows into tip
# Processed 490000 rows into tip
# Processed 500000 rows into tip
# Processed 510000 rows into tip
# Processed 520000 rows into tip
# Processed 530000 rows into tip
# Processed 540000 rows into tip
# Processed 550000 rows into tip
# Processed 560000 rows into tip
# Processed 570000 rows into tip
# Processed 580000 rows into tip
# Processed 590000 rows into tip
# Processed 600000 rows into tip
# Processed 610000 rows into tip
# Processed 620000 rows into tip
# Processed 630000 rows into tip
# Processed 640000 rows into tip
# Processed 650000 rows into tip
# Processed 660000 rows into tip
# Processed 670000 rows into tip
# Processed 680000 rows into tip
# Processed 690000 rows into tip
# Processed 700000 rows into tip
# Processed 710000 rows into tip
# Processed 720000 rows into tip
# Processed 730000 rows into tip
# Processed 740000 rows into tip
# Processed 750000 rows into tip
# Processed 760000 rows into tip
# Processed 770000 rows into tip
# Processed 780000 rows into tip
# Processed 790000 rows into tip
# Processed 800000 rows into tip
# Processed 810000 rows into tip
# Processed 820000 rows into tip
# Processed 830000 rows into tip
# Processed 840000 rows into tip
# Processed 850000 rows into tip
# Processed 860000 rows into tip
# Processed 870000 rows into tip
# Processed 880000 rows into tip
# Processed 890000 rows into tip
# Processed 900000 rows into tip
# Processed 8915 remaining rows into tip
# Processing F:\Portfolio Projects\User Engagement Analysis\yelp_dataset\yelp_academic_dataset_user.json for table user
# Processed 10000 rows into user
# Processed 20000 rows into user
# Processed 30000 rows into user
# Processed 40000 rows into user
# Processed 50000 rows into user
# Processed 60000 rows into user
# Processed 70000 rows into user
# Processed 80000 rows into user
# Processed 90000 rows into user
# Processed 100000 rows into user
# Processed 110000 rows into user
# Processed 120000 rows into user
# Processed 130000 rows into user
# Processed 140000 rows into user
# Processed 150000 rows into user
# Processed 160000 rows into user
# Processed 170000 rows into user
# Processed 180000 rows into user
# Processed 190000 rows into user
# Processed 200000 rows into user
# Processed 210000 rows into user
# Processed 220000 rows into user
# Processed 230000 rows into user
# Processed 240000 rows into user
# Processed 250000 rows into user
# Processed 260000 rows into user
# Processed 270000 rows into user
# Processed 280000 rows into user
# Processed 290000 rows into user
# Processed 300000 rows into user
# Processed 310000 rows into user
# Processed 320000 rows into user
# Processed 330000 rows into user
# Processed 340000 rows into user
# Processed 350000 rows into user
# Processed 360000 rows into user
# Processed 370000 rows into user
# Processed 380000 rows into user
# Processed 390000 rows into user
# Processed 400000 rows into user
# Processed 410000 rows into user
# Processed 420000 rows into user
# Processed 430000 rows into user
# Processed 440000 rows into user
# Processed 450000 rows into user
# Processed 460000 rows into user
# Processed 470000 rows into user
# Processed 480000 rows into user
# Processed 490000 rows into user
# Processed 500000 rows into user
# Processed 510000 rows into user
# Processed 520000 rows into user
# Processed 530000 rows into user
# Processed 540000 rows into user
# Processed 550000 rows into user
# Processed 560000 rows into user
# Processed 570000 rows into user
# Processed 580000 rows into user
# Processed 590000 rows into user
# Processed 600000 rows into user
# Processed 610000 rows into user
# Processed 620000 rows into user
# Processed 630000 rows into user
# Processed 640000 rows into user
# Processed 650000 rows into user
# Processed 660000 rows into user
# Processed 670000 rows into user
# Processed 680000 rows into user
# Processed 690000 rows into user
# Processed 700000 rows into user
# Processed 710000 rows into user
# Processed 720000 rows into user
# Processed 730000 rows into user
# Processed 740000 rows into user
# Processed 750000 rows into user
# Processed 760000 rows into user
# Processed 770000 rows into user
# Processed 780000 rows into user
# Processed 790000 rows into user
# Processed 800000 rows into user
# Processed 810000 rows into user
# Processed 820000 rows into user
# Processed 830000 rows into user
# Processed 840000 rows into user
# Processed 850000 rows into user
# Processed 860000 rows into user
# Processed 870000 rows into user
# Processed 880000 rows into user
# Processed 890000 rows into user
# Processed 900000 rows into user
# Processed 910000 rows into user
# Processed 920000 rows into user
# Processed 930000 rows into user
# Processed 940000 rows into user
# Processed 950000 rows into user
# Processed 960000 rows into user
# Processed 970000 rows into user
# Processed 980000 rows into user
# Processed 990000 rows into user
# Processed 1000000 rows into user
# Processed 1010000 rows into user
# Processed 1020000 rows into user
# Processed 1030000 rows into user
# Processed 1040000 rows into user
# Processed 1050000 rows into user
# Processed 1060000 rows into user
# Processed 1070000 rows into user
# Processed 1080000 rows into user
# Processed 1090000 rows into user
# Processed 1100000 rows into user
# Processed 1110000 rows into user
# Processed 1120000 rows into user
# Processed 1130000 rows into user
# Processed 1140000 rows into user
# Processed 1150000 rows into user
# Processed 1160000 rows into user
# Processed 1170000 rows into user
# Processed 1180000 rows into user
# Processed 1190000 rows into user
# Processed 1200000 rows into user
# Processed 1210000 rows into user
# Processed 1220000 rows into user
# Processed 1230000 rows into user
# Processed 1240000 rows into user
# Processed 1250000 rows into user
# Processed 1260000 rows into user
# Processed 1270000 rows into user
# Processed 1280000 rows into user
# Processed 1290000 rows into user
# Processed 1300000 rows into user
# Processed 1310000 rows into user
# Processed 1320000 rows into user
# Processed 1330000 rows into user
# Processed 1340000 rows into user
# Processed 1350000 rows into user
# Processed 1360000 rows into user
# Processed 1370000 rows into user
# Processed 1380000 rows into user
# Processed 1390000 rows into user
# Processed 1400000 rows into user
# Processed 1410000 rows into user
# Processed 1420000 rows into user
# Processed 1430000 rows into user
# Processed 1440000 rows into user
# Processed 1450000 rows into user
# Processed 1460000 rows into user
# Processed 1470000 rows into user
# Processed 1480000 rows into user
# Processed 1490000 rows into user
# Processed 1500000 rows into user
# Processed 1510000 rows into user
# Processed 1520000 rows into user
# Processed 1530000 rows into user
# Processed 1540000 rows into user
# Processed 1550000 rows into user
# Processed 1560000 rows into user
# Processed 1570000 rows into user
# Processed 1580000 rows into user
# Processed 1590000 rows into user
# Processed 1600000 rows into user
# Processed 1610000 rows into user
# Processed 1620000 rows into user
# Processed 1630000 rows into user
# Processed 1640000 rows into user
# Processed 1650000 rows into user
# Processed 1660000 rows into user
# Processed 1670000 rows into user
# Processed 1680000 rows into user
# Processed 1690000 rows into user
# Processed 1700000 rows into user
# Processed 1710000 rows into user
# Processed 1720000 rows into user
# Processed 1730000 rows into user
# Processed 1740000 rows into user
# Processed 1750000 rows into user
# Processed 1760000 rows into user
# Processed 1770000 rows into user
# Processed 1780000 rows into user
# Processed 1790000 rows into user
# Processed 1800000 rows into user
# Processed 1810000 rows into user
# Processed 1820000 rows into user
# Processed 1830000 rows into user
# Processed 1840000 rows into user
# Processed 1850000 rows into user
# Processed 1860000 rows into user
# Processed 1870000 rows into user
# Processed 1880000 rows into user
# Processed 1890000 rows into user
# Processed 1900000 rows into user
# Processed 1910000 rows into user
# Processed 1920000 rows into user
# Processed 1930000 rows into user
# Processed 1940000 rows into user
# Processed 1950000 rows into user
# Processed 1960000 rows into user
# Processed 1970000 rows into user
# Processed 1980000 rows into user
# Processed 7897 remaining rows into user
# All datasets processed and loaded into the database.

# %%
engine = create_engine('sqlite:///yelp_optimized.db')

# %%
# Inspect the table structure
df = pd.read_sql("select * from business limit 5;", con=engine)
df.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           categories
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food

# %%
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(tables_query, con=engine)
print(tables)
# Out:
#        name
# 0  business
# 1   checkin
# 2    review
# 3       tip
# 4      user

# %%
business_df = pd.read_sql("SELECT * FROM business LIMIT 5;", con=engine)
checkin_df = pd.read_sql("SELECT * FROM checkin LIMIT 5;", con=engine)
review_df = pd.read_sql("SELECT * FROM review LIMIT 5;", con=engine)
tip_df = pd.read_sql("SELECT * FROM tip LIMIT 5;", con=engine)
user_df = pd.read_sql("SELECT * FROM user LIMIT 5;", con=engine)

# %%
# Check shapes
print(business_df.shape)
print(checkin_df.shape)
print(review_df.shape)
print(tip_df.shape)
print(user_df.shape)
# Out:
# (5, 12)
# (5, 2)
# (5, 9)
# (5, 5)
# (5, 22)
